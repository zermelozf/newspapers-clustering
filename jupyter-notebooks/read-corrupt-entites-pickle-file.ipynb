# %%
import gzip
import pickle

# %%
entities_json_file_name = '../data/entities.json.pickle'

def read_entities(entities_json_file_name):
    def read_file(postfix):
        with gzip.open(entities_json_file_name + postfix, 'rb') as infile:
            return pickle.load(infile)
    return read_file('.gz.0') + read_file('.gz.1')

# %%
# This needs around 5GB of RAM
data = read_entities(entities_json_file_name)

# %%
data[0]
# Out:
# (3,
#  '{\n  "language": "en",\n  "entities": [\n    {\n      "salience": 0.05783792585134506,\n      "mentions": [\n        {\n          "text": {\n            "beginOffset": 636,\n            "content": "social media users"\n          },\n          "sentiment": {},\n          "type": "COMMON"\n        }\n      ],\n      "name": "social media users",\n      "sentiment": {\n        "score": -0.10000000149011612,\n        "magnitude": 0.699999988079071\n      },\n      "type": "PERSON"\n    },\n    {\n      "salience": 0.05403602868318558,\n      "mentions": [\n        {\n          "text": {\n            "beginOffset": 27,\n            "content": "social media"\n          },\n          "sentiment": {},\n          "type": "COMMON"\n        }\n      ],\n      "name": "social media",\n      "sentiment": {},\n      "type": "OTHER"\n    },\n    {\n      "salience": 0.05193149298429489,\n      "mentions": [\n        {\n          "text": {\n            "beginOffset": 99,\n            "content": "thing"\n          },\n          "sentiment": {\n            "score": -0.4000000059604645,\n            "magnitude": 0.4000000059604645\n          },\n          "type": "COMMON"\n        }\n      ],\n      "name": "thing",\n      "sentiment": {\n        "score": -0.4000000059604645,\n        "magnitude": 0.4000000059604645\n      },\n      "type": "OTHER"\n    },\n    {\n      "salience": 0.04337674006819725,\n      "mentions": [\n        {\n          "text": {\n            "beginOffset": 50,\n            "content": "culture"\n          },\n          "sentiment": {\n            "score": -0.10000000149011612,\n            "magnitude": 0.10000000149011612\n          },\n          "type": "COMMON"\n        }\n      ],\n      "name": "culture",\n      "sentiment": {\n        "score": -0.10000000149011612,\n        "magnitude": 0.10000000149011612\n      },\n      "type": "OTHER"\n    },\n    {\n      "salience": 0.038134753704071045,\n      "mentions": [\n        {\n          "text": {\n            "beginOffset": 110,\n            "content": "secret"\n          },\n          "sentiment": {\n            "score": -0.10000000149011612,\n            "magnitude": 0.10000000149011612\n          },\n          "type": "COMMON"\n        }\n      ],\n      "name": "secret",\n      "sentiment": {\n        "score": -0.10000000149011612,\n        "magnitude": 0.10000000149011612\n      },\n      "type": "OTHER"\n    },\n    {\n      "salience": 0.02684831991791725,\n      "mentions": [\n        {\n          "text": {\n            "beginOffset": 161,\n            "content": "lives"\n          },\n          "sentiment": {},\n          "type": "COMMON"\n        }\n      ],\n      "name": "lives",\n      "sentiment": {},\n      "type": "OTHER"\n    },\n    {\n      "salience": 0.025801848620176315,\n      "mentions": [\n        {\n          "text": {\n            "beginOffset": 127,\n            "content": "People"\n          },\n          "sentiment": {\n            "score": -0.10000000149011612,\n            "magnitude": 0.10000000149011612\n          },\n          "type": "COMMON"\n        }\n      ],\n      "name": "People",\n      "sentiment": {\n        "score": -0.10000000149011612,\n        "magnitude": 0.20000000298023224\n      },\n      "type": "PERSON"\n    },\n    {\n      "salience": 0.02329975739121437,\n      "mentions": [\n        {\n          "text": {\n            "beginOffset": 1044,\n            "content": "everybody"\n          },\n          "sentiment": {\n            "score": 0.30000001192092896,\n            "magnitude": 0.30000001192092896\n          },\n          "type": "COMMON"\n        }\n      ],\n      "name": "everybody",\n      "sentiment": {\n        "score": 0.20000000298023224,\n        "magnitude": 0.800000011920929\n      },\n      "type": "PERSON"\n    },\n    {\n      "salience": 0.02251526527106762,\n      "mentions": [\n        {\n          "text": {\n            "beginOffset": 11,\n            "content": "Starbox"\n          }, ...
